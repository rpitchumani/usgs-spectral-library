# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import pandas as pd
import plotly.graph_objects as go
from splib07a import SPLIB07A
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path_main_usgs = Path("../../data-sets/usgs/splib07")

# %%
splib = SPLIB07A(path_main_usgs=path_main_usgs)
# Out:
# 2023-10-18 17:58:08.395 | INFO     | splib07a:_read_index_datatable:71 - Found 7:
# ['Chapter 1: Minerals', 'Chapter 2: Soils and Mixtures', 'Chapter 3: Coatings', 'Chapter 4: Liquids', 'Chapter 5: Organic Compounds', 'Chapter 6: Artificial Materials', 'Chapter 7: Vegetation']

# %%
material_name = "Actinolite HS116.2B"

# %%
dict_wavelength = splib.get_wavelength(material_name=material_name)

# %%
plotly_wavelength = splib.plotly_wavelength(dict_wavelength)
plotly_wavelength.show()

# %%
fig_wavelength = splib.plot_wavelength(dict_wavelength)
